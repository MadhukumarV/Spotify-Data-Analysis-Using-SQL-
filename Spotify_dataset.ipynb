# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("E:/downloads/spotify_dataset.csv")
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20589  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20590  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20591  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20592  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20593  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
df.head(10)
# Out:
#      Artist                                              Track  \
# 0  Gorillaz                                     Feel Good Inc.
# 1  Gorillaz                                    Rhinestone Eyes
# 2  Gorillaz      New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                                 On Melancholy Hill
# 4  Gorillaz                                     Clint Eastwood
# 5  Gorillaz                                               DARE
# 6  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown) ...
# 7  Gorillaz                 She's My Collar (feat. Kali Uchis)
# 8  Gorillaz                  Cracker Island (feat. Thundercat)
# 9  Gorillaz                                        Dirty Harry
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# ...

# %%
df.tail(10)
# Out:
#             Artist                                   Track  \
# 20584  SICK LEGEND          PART OF ME HARDSTYLE (SPED UP)
# 20585  SICK LEGEND           SUMMER TIME SADNESS HARDSTYLE
# 20586  SICK LEGEND                    PART OF ME HARDSTYLE
# 20587  SICK LEGEND   MIDDLE OF THE NIGHT - HARDSTYLE REMIX
# 20588  SICK LEGEND  EVERYTIME WE TOUCH HARDSTYLE (SPED UP)
# 20589  SICK LEGEND                    JUST DANCE HARDSTYLE
# 20590  SICK LEGEND          SET FIRE TO THE RAIN HARDSTYLE
# 20591  SICK LEGEND               OUTSIDE HARDSTYLE SPED UP
# 20592  SICK LEGEND                     ONLY GIRL HARDSTYLE
# 20593  SICK LEGEND                      MISS YOU HARDSTYLE
#
#                                         Album Album_type  Danceability  \
# 20584          PART OF ME HARDSTYLE (SPED UP)     single         0.642
# 20585           SUMMER TIME SADNESS HARDSTYLE     single         0.490
# 20586                    PART OF ME HARDSTYLE     single         0.519
# ...

# %%
df.dtypes
# Out:
# Artist               object
# Track                object
# Album                object
# Album_type           object
# Danceability        float64
# Energy              float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_min        float64
# Title                object
# Channel              object
# Views                 int64
# Likes                 int64
# Comments              int64
# Licensed             object
# official_video       object
# Stream                int64
# EnergyLiveness      float64
# most_playedon        object
# dtype: object

# %%
df.describe()
# Out:
#        Danceability        Energy      Loudness   Speechiness  Acousticness  \
# count  20594.000000  20594.000000  20594.000000  20594.000000  20594.000000
# mean       0.620102      0.635176     -7.678254      0.096733      0.291391
# std        0.165504      0.214274      4.639481      0.112182      0.286117
# min        0.000000      0.000000    -46.251000      0.000000      0.000000
# 25%        0.519000      0.507000     -8.868000      0.035700      0.045200
# 50%        0.638000      0.666000     -6.540500      0.050650      0.193000
# 75%        0.741000      0.798000     -4.935000      0.104000      0.476750
# max        0.975000      1.000000      0.920000      0.964000      0.996000
#
#        Instrumentalness      Liveness       Valence         Tempo  \
# count      20594.000000  20594.000000  20594.000000  20594.000000
# mean           0.056162      0.193653      0.530077    120.562616
# std            0.193622      0.168832      0.245542     29.588093
# ...

# %%
df.isnull().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_min        0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# EnergyLiveness      2
# most_playedon       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_min        0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# EnergyLiveness      0
# most_playedon       0
# dtype: int64
